# %% [markdown]
# <a href="https://colab.research.google.com/github/laresamdeola/Machine-Learning/blob/main/AWS_Cloud_Experiments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import json
import csv

# %%
with open('aws cloud experiments deolu.json', 'r') as file:
  data = json.load(file)

# %%
print(data)
# Out:
# {'Records': [{'eventVersion': '1.09', 'userIdentity': {'type': 'Root', 'principalId': '058264352014', 'arn': 'arn:aws:iam::058264352014:root', 'accountId': '058264352014', 'accessKeyId': 'ASIAQ3EGTOUHCWANEMMA', 'sessionContext': {'attributes': {'creationDate': '2024-05-20T19:46:03Z', 'mfaAuthenticated': 'false'}}}, 'eventTime': '2024-05-20T20:08:54Z', 'eventSource': 'athena.amazonaws.com', 'eventName': 'StartQueryExecution', 'awsRegion': 'eu-west-2', 'sourceIPAddress': '86.13.140.155', 'userAgent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36', 'requestParameters': {'queryString': '***OMITTED***', 'clientRequestToken': 'f4d41c8a-97ca-4f61-a10c-6b9ccc8950ac', 'queryExecutionContext': {'database': 'default', 'catalog': 'AwsDataCatalog'}, 'resultConfiguration': {'outputLocation': 's3://aws-cloudtrail-logs-058264352014-8546e3f4/Unsaved/2024/05/20/'}, 'workGroup': 'primary', 'resultReuseConfiguration': {'resultReuseByAgeConfiguration': {'enabled': False}}}, 'responseElements': {'queryExecutionId': '0406eb3e-d8cf-4a0e-99d3-c9ffdbacc46e'}, 'requestID': 'f9e790f2-7afd-4060-aaf7-43f1ed45f6a1', 'eventID': '516b4e19-9af5-415f-a6e3-85571d9e8912', 'readOnly': False, 'eventType': 'AwsApiCall', 'managementEvent': True, 'recipientAccountId': '058264352014', 'eventCategory': 'Management', 'tlsDetails': {'tlsVersion': 'TLSv1.3', 'cipherSuite': 'TLS_AES_128_GCM_SHA256', 'clientProvidedHostHeader': 'athena.eu-west-2.amazonaws.com'}, 'sessionCredentialFromConsole': 'true'}, {'eventVersion': '1.09', 'userIdentity': {'type': 'Root', 'principalId': '058264352014', 'arn': 'arn:aws:iam::058264352014:root', 'accountId': '058264352014', 'accessKeyId': 'ASIAQ3EGTOUHCWANEMMA', 'sessionContext': {'attributes': {'creationDate': '2024-05-20T19:46:03Z', 'mfaAuthenticated': 'false'}}}, 'eventTime': '2024-05-20T20:07:22Z', 'eventSource': 'athena.amazonaws.com', 'eventName': 'StartQueryExecution', 'awsRegion': 'eu-west-2', 'sourceIPAddress': '86.13.140.155', 'userAgent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36', 'requestParameters': {'queryString': '***OMITTED***', 'clientRequestToken': '6080c108-f639-4261-ad84-8107356f5cff', 'queryExecutionContext': {'database': 'default', 'catalog': 'AwsDataCatalog'}, 'resultConfiguration': {'outputLocation': 's3://aws-cloudtrail-logs-058264352014-8546e3f4/Unsaved/2024/05/20/'}, 'workGroup': 'primary', 'resultReuseConfiguration': {'resultReuseByAgeConfiguration': {'enabled': False}}}, 'responseElements': {'queryExecutionId': '4f6c3fde-d2e3-41ae-bb7f-2d091d08ca50'}, 'requestID': 'd9b389cc-bbb5-4ffd-ac94-010def4468e6', 'eventID': 'c0aa106a-2be3-4dda-8b71-e7f6288369d6', 'readOnly': False, 'eventType': 'AwsApiCall', 'managementEvent': True, 'recipientAccountId': '058264352014', 'eventCategory': 'Management', 'tlsDetails': {'tlsVersion': 'TLSv1.3', 'cipherSuite': 'TLS_AES_128_GCM_SHA256', 'clientProvidedHostHeader': 'athena.eu-west-2.amazonaws.com'}, 'sessionCredentialFromConsole': 'true'}, {'eventVersion': '1.09', 'userIdentity': {'type': 'Root', 'principalId': '058264352014', 'arn': 'arn:aws:iam::058264352014:root', 'accountId': '058264352014', 'accessKeyId': 'ASIAQ3EGTOUHCWANEMMA', 'sessionContext': {'attributes': {'creationDate': '2024-05-20T19:46:03Z', 'mfaAuthenticated': 'false'}}}, 'eventTime': '2024-05-20T20:06:23Z', 'eventSource': 'athena.amazonaws.com', 'eventName': 'StartQueryExecution', 'awsRegion': 'eu-west-2', 'sourceIPAddress': '86.13.140.155', 'userAgent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36', 'requestParameters': {'queryString': '***OMITTED***', 'clientRequestToken': 'dec5866c-9880-4472-87de-44eac898e1eb', 'queryExecutionContext': {'database': 'default', 'catalog': 'AwsDataCatalog'}, 'resultConfiguration': {'outputLocation': 's3://aws-cloudtrail-logs-058264352014-8546e3f4/Unsaved/2024/05/20/'}, 'workGr ...

# %%
data = data['Records']

# %%
type(data)
# Out:
# list

# %%
data = pd.DataFrame(data)

# %%
data.head()
# Out:
#   eventVersion                                       userIdentity  \
# 0         1.09  {'type': 'Root', 'principalId': '058264352014'...
# 1         1.09  {'type': 'Root', 'principalId': '058264352014'...
# 2         1.09  {'type': 'Root', 'principalId': '058264352014'...
# 3         1.09  {'type': 'Root', 'principalId': '058264352014'...
# 4         1.09  {'type': 'Root', 'principalId': '058264352014'...
#
#               eventTime           eventSource            eventName  awsRegion  \
# 0  2024-05-20T20:08:54Z  athena.amazonaws.com  StartQueryExecution  eu-west-2
# 1  2024-05-20T20:07:22Z  athena.amazonaws.com  StartQueryExecution  eu-west-2
# 2  2024-05-20T20:06:23Z  athena.amazonaws.com  StartQueryExecution  eu-west-2
# 3  2024-05-20T20:03:52Z  athena.amazonaws.com  StartQueryExecution  eu-west-2
# 4  2024-05-20T19:54:38Z  athena.amazonaws.com  StartQueryExecution  eu-west-2
#
#   sourceIPAddress                                          userAgent  \
# 0   86.13.140.155  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 1   86.13.140.155  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 2   86.13.140.155  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 3   86.13.140.155  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 4   86.13.140.155  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
#
#                                    requestParameters  \
# 0  {'queryString': '***OMITTED***', 'clientReques...
# 1  {'queryString': '***OMITTED***', 'clientReques...
# 2  {'queryString': '***OMITTED***', 'clientReques...
# 3  {'queryString': '***OMITTED***', 'clientReques...
# 4  {'queryString': '***OMITTED***', 'clientReques...
#
#                                     responseElements  ... eventCategory  \
# 0  {'queryExecutionId': '0406eb3e-d8cf-4a0e-99d3-...  ...    Management
# 1  {'queryExecutionId': '4f6c3fde-d2e3-41ae-bb7f-...  ...    Management
# 2  {'queryExecutionId': 'aee65850-12ae-4851-a652-...  ...    Management
# 3  {'queryExecutionId': '145d7e25-97d4-4d84-886c-...  ...    Management
# 4  {'queryExecutionId': 'd0a5b3d0-3e12-4d23-ba9f-...  ...    Management
#
#                                           tlsDetails  \
# 0  {'tlsVersion': 'TLSv1.3', 'cipherSuite': 'TLS_...
# 1  {'tlsVersion': 'TLSv1.3', 'cipherSuite': 'TLS_...
# 2  {'tlsVersion': 'TLSv1.3', 'cipherSuite': 'TLS_...
# 3  {'tlsVersion': 'TLSv1.3', 'cipherSuite': 'TLS_...
# 4  {'tlsVersion': 'TLSv1.3', 'cipherSuite': 'TLS_...
#
#    sessionCredentialFromConsole errorCode  errorMessage additionalEventData  \
# 0                          true       NaN           NaN                 NaN
# 1                          true       NaN           NaN                 NaN
# 2                          true       NaN           NaN                 NaN
# 3                          true       NaN           NaN                 NaN
# 4                          true       NaN           NaN                 NaN
#
#   resources sharedEventID serviceEventDetails apiVersion
# 0       NaN           NaN                 NaN        NaN
# 1       NaN           NaN                 NaN        NaN
# 2       NaN           NaN                 NaN        NaN
# 3       NaN           NaN                 NaN        NaN
# 4       NaN           NaN                 NaN        NaN
#
# [5 rows x 26 columns]

# %%
data.tail()
# Out:
#     eventVersion                                       userIdentity  \
# 451         1.10  {'type': 'Root', 'principalId': '058264352014'...
# 452         1.10  {'type': 'Root', 'principalId': '058264352014'...
# 453         1.09  {'type': 'Root', 'principalId': '058264352014'...
# 454         1.09  {'type': 'Root', 'principalId': '058264352014'...
# 455         1.09  {'type': 'Root', 'principalId': '058264352014'...
#
#                 eventTime               eventSource            eventName  \
# 451  2024-03-19T15:22:36Z  cloudtrail.amazonaws.com          CreateTrail
# 452  2024-03-19T15:22:36Z  cloudtrail.amazonaws.com    PutEventSelectors
# 453  2024-03-19T15:22:35Z          s3.amazonaws.com  PutBucketEncryption
# 454  2024-03-19T15:22:34Z          s3.amazonaws.com      PutBucketPolicy
# 455  2024-03-19T15:22:34Z          s3.amazonaws.com         CreateBucket
#
#      awsRegion  sourceIPAddress  \
# 451  eu-west-2  105.112.238.187
# 452  eu-west-2  105.112.238.187
# 453  eu-west-2  105.112.238.187
# 454  eu-west-2  105.112.238.187
# 455  eu-west-2  105.112.238.187
#
#                                              userAgent  \
# 451  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 452  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 453  [Mozilla/5.0 (Windows NT 10.0; Win64; x64) App...
# 454  [Mozilla/5.0 (Windows NT 10.0; Win64; x64) App...
# 455  [Mozilla/5.0 (Windows NT 10.0; Win64; x64) App...
#
#                                      requestParameters  \
# 451  {'name': 'My-management-event-trails', 's3Buck...
# 452  {'trailName': 'arn:aws:cloudtrail:eu-west-2:05...
# 453  {'bucketName': 'aws-cloudtrail-logs-0582643520...
# 454  {'bucketPolicy': {'Version': '2012-10-17', 'St...
# 455  {'CreateBucketConfiguration': {'LocationConstr...
#
#                                       responseElements  ... eventCategory  \
# 451  {'name': 'My-management-event-trails', 's3Buck...  ...    Management
# 452  {'trailARN': 'arn:aws:cloudtrail:eu-west-2:058...  ...    Management
# 453                                               None  ...    Management
# 454                                               None  ...    Management
# 455                                               None  ...    Management
#
#                                             tlsDetails  \
# 451  {'tlsVersion': 'TLSv1.3', 'cipherSuite': 'TLS_...
# 452  {'tlsVersion': 'TLSv1.3', 'cipherSuite': 'TLS_...
# 453  {'tlsVersion': 'TLSv1.2', 'cipherSuite': 'ECDH...
# 454  {'tlsVersion': 'TLSv1.2', 'cipherSuite': 'ECDH...
# 455  {'tlsVersion': 'TLSv1.2', 'cipherSuite': 'ECDH...
#
#      sessionCredentialFromConsole errorCode  errorMessage  \
# 451                          true       NaN           NaN
# 452                          true       NaN           NaN
# 453                           NaN       NaN           NaN
# 454                           NaN       NaN           NaN
# 455                           NaN       NaN           NaN
#
#                                    additionalEventData  \
# 451                                                NaN
# 452                                                NaN
# 453  {'SignatureVersion': 'SigV4', 'CipherSuite': '...
# 454  {'SignatureVersion': 'SigV4', 'CipherSuite': '...
# 455  {'SignatureVersion': 'SigV4', 'CipherSuite': '...
#
#                                              resources sharedEventID  \
# 451                                                NaN           NaN
# 452                                                NaN           NaN
# 453  [{'accountId': '058264352014', 'type': 'AWS::S...           NaN
# 454  [{'accountId': '058264352014', 'type': 'AWS::S...           NaN
# 455                                                NaN           NaN
#
#     serviceEventDetails apiVersion
# 451                 NaN        NaN
# 452                 NaN        NaN
# 453                 NaN        NaN
# 454                 NaN        NaN
# 455                 NaN        NaN
#
# [5 rows x 26 columns]

# %%
len(data)
# Out:
# 456

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.to_csv('aws cloud experiments deolu.csv', index=False)
